# %%
# %sql
grant all privileges on catalog catalog_comercial to `bigdatavillano@outlook.com`;
grant create, use schema on schema catalog_comercial.bronze to `bigdatavillano@outlook.com`;
grant create, use schema on schema catalog_comercial.silver to `bigdatavillano@outlook.com`;
grant create, use schema on schema catalog_comercial.golden to `bigdatavillano@outlook.com`;


grant all privileges on catalog catalog_comercial to `dataengAI `;
grant create, use schema on schema catalog_comercial.bronze to `dataengAI `;
grant create, use schema on schema catalog_comercial.silver to `dataengAI `;
grant create, use schema on schema catalog_comercial.golden to `dataengAI `;

# %%
# %sql
grant read files, write files on external location `extl_bronze`to `bigdatavillano@outlook.com`;
grant read files, write files on external location `extl_silver`to `bigdatavillano@outlook.com`;
grant read files, write files on external location `extl_golden`to `bigdatavillano@outlook.com`;

grant read files, write files on external location `extl_bronze`to `dataengAI`;
grant read files, write files on external location `extl_silver`to `dataengAI`;
grant read files, write files on external location `extl_golden`to `dataengAI`;
