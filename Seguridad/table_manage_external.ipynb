# %%
# %sql

USE CATALOG adbwsjhsvdesa01_7405607127755800;

# %%
# %sql
create table if not exists tabla_manage(
width int,
height int,
length int
);

insert into tabla_manage values (1,2,3);

# %%
# %sql
DESCRIBE EXTENDED adbwsjhsvdesa01_7405607127755800.default.tabla_manage

# %%
# %sql
SELECT current_catalog(),current_database(),current_metastore(),current_schema()

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS new_default;

# %%
# %sql
create table if not exists adbwsjhsvdesa01_7405607127755800.new_default.tabla_manage(
width int,
height int,
length int
);

# %%
# %sql
describe database extended adbwsjhsvdesa01_7405607127755800.new_default;

# %%
# %fs ls "dbfs:/Workspace/"

# %%
# %sql
drop table adbwsjhsvdesa01_7405607127755800.new_default.tabla_manage;

# %% [markdown]
# # CREATING DELTA LAKE TABLES

# %%
# %sql
CREATE TABLE IF NOT EXISTS adbwsjhsvdesa01_7405607127755800.default.employees(
id int,
name string,
salary double
);

# %%
# %sql
insert  into adbwsjhsvdesa01_7405607127755800.default.employees values(1,'JOHAN',8000);
insert  into adbwsjhsvdesa01_7405607127755800.default.employees values(2,'EVA',3000);
insert  into adbwsjhsvdesa01_7405607127755800.default.employees values(3,'JUANA',5000);
insert  into adbwsjhsvdesa01_7405607127755800.default.employees values(4,'MARILIN',7000);
insert  into adbwsjhsvdesa01_7405607127755800.default.employees values(5,'OBTAVIO',9000);

# %%
# %sql
SELECT * FROM adbwsjhsvdesa01_7405607127755800.default.employees;

# %%
# %sql
describe  extended adbwsjhsvdesa01_7405607127755800.default.employees;

# %%
# %sql
describe detail  adbwsjhsvdesa01_7405607127755800.default.employees;

# %%
# %sql
describe history adbwsjhsvdesa01_7405607127755800.default.employees;

# %%
# %sql
UPDATE adbwsjhsvdesa01_7405607127755800.default.employees
SET salary = salary * (1 + 0.25)

# %%
# %sql
create table if not exists adbwsjhsvdesa01_7405607127755800.new_default.table_parquet
(
id int,
name string
)
using parquet;

-- no puedo crear tablas parquet de tipo manage

# %%
# %sql
describe history adbwsjhsvdesa01_7405607127755800.default.employees;

# %%
# %sql
-- regresando en el versionanmiento de la historia de la tabla employees
select * from  adbwsjhsvdesa01_7405607127755800.default.employees order by id;

# %%
# %sql
select * from  adbwsjhsvdesa01_7405607127755800.default.employees version as of 6;

# %%
# %sql
select * from  adbwsjhsvdesa01_7405607127755800.default.employees@v6;

# %%
# %sql
delete from adbwsjhsvdesa01_7405607127755800.default.employees where id=5;

# %%
# %sql
describe history adbwsjhsvdesa01_7405607127755800.default.employees;

# %%
# %sql
select * from adbwsjhsvdesa01_7405607127755800.default.employees version as of 7;

# %% [markdown]
# # RESTAURANDO A UNA VERSION ESTABLE POR ALGUNA EQUIVOCACION EN ESTE EJEMPLO ES EL DELETE

# %%
# %sql
restore table adbwsjhsvdesa01_7405607127755800.default.employees to version as of 6;

# %%
# %sql
describe history adbwsjhsvdesa01_7405607127755800.default.employees;

# %%
# %sql
describe detail adbwsjhsvdesa01_7405607127755800.default.employees;

# %% [markdown]
# # USANDO EL OPTIMAZE

# %%
# %sql
optimize  adbwsjhsvdesa01_7405607127755800.default.employees zorder by id;

# %%
# %sql
describe detail adbwsjhsvdesa01_7405607127755800.default.employees;

# %%
# %sql
describe history adbwsjhsvdesa01_7405607127755800.default.employees;

# %% [markdown]
# # DELTA TIME TRAVEL

# %%
# %sql

--VACUUM DE FORMA PREDETERMINADA SON DE 68 HORAS O 
VACUUM adbwsjhsvdesa01_7405607127755800.default.employees
