# %%
# %sql
revoke read files, write files on external location `extl_bronze` from `bigdatavillano@outlook.com`;
revoke read files, write files on external location `extl_silver` from `bigdatavillano@outlook.com`;
revoke read files, write files on external location `extl_golden` from `bigdatavillano@outlook.com`;

revoke read files, write files on external location `extl_bronze` from `dataengAI`;
revoke read files, write files on external location `extl_silver` from `dataengAI`;
revoke read files, write files on external location `extl_golden` from `dataengAI`;
